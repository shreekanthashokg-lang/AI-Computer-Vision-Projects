# %% [markdown]
# #  Introduction to Computer Vision & Image Processing Basics

# %% [markdown]
# ####
#
#     Computer Vision (CV) is a branch of Artificial Intelligence (AI) that enables computers to see, understand, analyze, and make decisions  from digital images and videos, similar to how humans use their eyes and brain.

# %% [markdown]
# ####
#     Image Processing, on the other hand, focuses on manipulating and enhancing images to improve their quality or extract useful information.

# %% [markdown]
# ##

# %% [markdown]
# ### Hands-On

# %% [markdown]
# ##

# %% [markdown]
# ### Installing OpenCV Library for Computer Vision

# %%
# !pip install opencv-python matplotlib

# %% [markdown]
# ### Importing OpenCV and other lib

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read, Write , Save Images

# %% [markdown]
# ###

# %% [markdown]
# ### Reading an Image

# %%
img = cv2.imread("my_car.jpeg")

# %% [markdown]
# ### Displaying an Image

# %%
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Saving an Image

# %%
cv2.imwrite("output.jpg", img)
# Out:
# True

# %% [markdown]
# ### Checking Shape of the Image

# %%
img.shape  # Dimensions
# Out:
# (430, 721, 3)
