# %% [markdown]
# ## VIDEO PROCESSING WITH OPENCV

# %% [markdown]
# ###
#
#     Video Processing is the technique of analyzing, modifying, or enhancing a video by processing each frame individually to perform tasks such as filtering, object detection, tracking, recognition, and visual enhancement.

# %%
import cv2
cap = cv2.VideoCapture('flower_v.mp4') # already this video is present in system

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
    resized = cv2.resize(frame , (1020,850))    
    cv2.imshow('Playback', resized)

    # To close the video manually
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #

# %% [markdown]
# ### Capturing images using web camera

# %%
# import cv2

# Open the default webcam (0)
cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = cap.read()  
    
    '''it's reading the webcam and return frame and ret ,
    frame is single image at each instance and ret is checking whether the the webcam is reading the frame successfully or not''' 
    
    # If frame is not captured properly
    if not ret:
        print("Failed to grab frame")
        break

    # Show the live webcam feed
    cv2.imshow("Webcam - Press 's' to save, 'q' to quit", frame)

    key = cv2.waitKey(1)

    # Press 's' to save image
    if key == ord('s'):
        cv2.imwrite("captured_image.jpg", frame)
        print("Image saved successfully!")

    # Press 'q' to quit
    elif key == ord('q'):
        break

# Release camera and close window
cap.release()
cv2.destroyAllWindows()
# Out:
# Image saved successfully!
# Image saved successfully!
# Image saved successfully!
# Image saved successfully!

# %% [markdown]
# ### Reading Video and Displaying it

# %%
cap = cv2.VideoCapture('car_video.mp4') # already this video is present in system

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
        
    cv2.imshow('Playback', frame)

    # To close the video manually
    if cv2.waitKey(70) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Convert Video to Grayscale

# %%
import cv2

cap = cv2.VideoCapture("car_video.mp4")

while True:
    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow("Grayscale Video", gray)

    if cv2.waitKey(15) & 0xFF == ord('q'):    ### hexadecimal format , 
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Resize Video Frame

# %%
# Open webcam (0) or replace with video file path

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

   
    #  Resize video frame
    
    resized_frame = cv2.resize(frame, (700, 780))

    # Show output
    
    cv2.imshow("Video Manipulation", resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Flip video Frame

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # performing flipping ( vertical flip )
    flipped = cv2.flip(frame, 0)

    cv2.imshow("Flip", flipped)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #

# %% [markdown]
# ## Drawing shapes on video

# %% [markdown]
# ###

# %% [markdown]
# #### Drawing Rectangle on Video

# %%
# Open webcam (0) or replace with video file path
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break

     
    
    resized_frame = cv2.resize(frame, (640, 480))    

    cv2.rectangle(
        resized_frame,          # image
        (100, 100),               # top-left corner
        (300, 400),             # bottom-right corner
        (255, 0, 0),            # color (BGR)
        15                      # thickness
    )
   

    # Show output
    cv2.imshow("Video Manipulation", resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### Drawing Circle on Video

# %%
# Open webcam (0) or replace with video file path
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break
    
    resized_frame = cv2.resize(frame, (640, 480))

    cv2.circle(
        resized_frame,          # image
        (350, 300),             # center point
        150,                     # radius
        (255, 0, 255),            # color (BGR)
        3                     # thickness
    )

    # Show output
    cv2.imshow("Video Manipulation", resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### Drawing Line on Video

# %%
# Open webcam (0) or replace with video file path
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break
    
    resized_frame = cv2.resize(frame, (640, 480))
    cv2.line(
        resized_frame,          # image
        (0, 0),                 # start point
        (640, 480),             # end point
        (0, 0, 255),            # color (BGR)
        2                       # thickness
    )

    # Show output
    cv2.imshow("Video Manipulation", resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### Drawing Text on Video

# %%
# Open webcam (0) or replace with video file path
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break
    
    resized_frame = cv2.resize(frame, (640, 480))

    
    cv2.putText(
        resized_frame,          # image
        "Welcome to Innomatics,  Tapaswani",    # text
        (25, 40),               # position
        cv2.FONT_ITALIC,  # font
        1,                      # font scale
        (255, 0, 255),        # color
        2,                      # thickness
        cv2.LINE_AA        # line type
    )
    

    # Show output
    cv2.imshow("Video Manipulation", resized_frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Bitwise Operations on Videos (Live Example) - Masking

# %% [markdown]
# ### Recap :
#
# ![image.png](attachment:00846610-717b-406c-9e70-32788a9a0749.png)

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Create black mask
    mask = np.zeros(frame.shape[:2], dtype=np.uint8)

    # Draw white circle mask
    cv2.circle(mask, (frame.shape[1]//2, frame.shape[0]//2), 150, 255, -1)

    # Apply mask
    masked_frame = cv2.bitwise_and(frame, frame, mask=mask)

    cv2.imshow("Original", frame)
    cv2.imshow("Masked Video", masked_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### Bitwise Not on Video - Negatives of video/image

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    if not ret:
        break

    inverted = cv2.bitwise_not(frame)

    cv2.imshow("Original", frame)
    cv2.imshow("Inverted Video", inverted)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Store webcam Video - Recording webcam Video

# %%
# Import the OpenCV library
import cv2

# Open the default webcam (0 = primary webcam)
cap = cv2.VideoCapture(0)

# FOURCC = Four Character Code
# It specifies the video codec (compression format) used to save the video.

# Create a FOURCC codec for MP4 video format
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # MP4 video encoder

# Create a VideoWriter object to save the recorded video
# Parameters:
# 'output.mp4' -> Output file name
# fourcc       -> Video codec
# 20.0         -> Frames Per Second (FPS)
# (640, 480)   -> Frame resolution (Width, Height)
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (640,480))



# Start an infinite loop to continuously capture webcam frames
while True:

    # Read a frame from the webcam
    # ret   -> True if frame is captured successfully
    # frame -> Captured image/frame
    ret, frame = cap.read()

    # If frame capture fails, exit the loop
    if not ret:
        break

    # Write the current frame to the output video file
    out.write(frame)

    # Display the live webcam feed in a window named "Recording"
    cv2.imshow('Recording', frame)

    # Wait for 1 millisecond for a key press
    # If the user presses 'q', exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam resource
cap.release()

# Release the video writer and save the video file
out.release()

# Close all OpenCV windows
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:8cd2c83c-4906-4859-9253-f600acc03ef8.png)

# %% [markdown]
# ### Play Recorded Video

# %%
cap = cv2.VideoCapture('output.mp4')

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break
        
    cv2.imshow('Playback', frame)
    
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #

# %% [markdown]
# ## Face Detection using Haar Cascade

# %%
# Import the OpenCV library for computer vision operations
import cv2

# Import the time module for FPS (Frames Per Second) calculation
import time

# --------------------------------------------------
# Load Haar Cascade
# --------------------------------------------------

# Load the pre-trained Haar Cascade classifier for frontal face detection
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# Check whether the Haar Cascade file was loaded successfully
if face_cascade.empty():
    print("Error loading Haar Cascade.")
    exit()

# --------------------------------------------------
# Open Webcam
# --------------------------------------------------

# Open the default webcam (0 = primary webcam)
cap = cv2.VideoCapture(0)

# Check whether the webcam opened successfully
if not cap.isOpened():
    print("Unable to open webcam.")
    exit()

# Set webcam resolution to 1280 × 720 (HD)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Store the initial time for FPS calculation
prev_time = time.time()

# --------------------------------------------------
# Main Loop
# --------------------------------------------------

# Start an infinite loop to continuously process webcam frames
while True:

    # Capture one frame from the webcam
    # ret   -> True if frame is captured successfully
    # frame -> Captured image
    ret, frame = cap.read()

    # Exit the loop if frame capture fails
    if not ret:
        break

    # Convert the color image into grayscale
    # Haar Cascade works faster on grayscale images
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    faces = face_cascade.detectMultiScale(

        # Input grayscale image
        gray,

        # Image scaling factor for multi-scale detection
        scaleFactor=1.1,

        # Number of neighboring detections required
        # Higher value = fewer false detections
        minNeighbors=5,

        # Minimum face size to detect
        minSize=(40, 40)
    )

    # Draw Bounding Boxes
    # Loop through every detected face
    for (x, y, w, h) in faces:

        # Draw a green rectangle around the detected face
        cv2.rectangle(

            # Input image
            frame,

            # Top-left corner
            (x, y),

            # Bottom-right corner
            (x + w, y + h),

            # Rectangle color (Green)
            (0, 255, 0),

            # Rectangle thickness
            2
        )

        # Display the label "Face" above the bounding box
        cv2.putText(

            # Input image
            frame,

            # Text to display
            "Face",

            # Text position
            (x, y - 10),

            # Font style
            cv2.FONT_HERSHEY_COMPLEX,

            # Font size
            0.6,

            # Text color (Green)
            (0, 255, 0),

            # Text thickness
            2
        )

    # --------------------------------------------------
    # FPS Calculation
    # --------------------------------------------------

    # Get the current time
    current_time = time.time()

    # Calculate Frames Per Second (FPS)
    fps = 1 / (current_time - prev_time)

    # Update previous time for the next frame
    prev_time = current_time

    # --------------------------------------------------
    # Display FPS
    # --------------------------------------------------

    # Display FPS on the top-left corner of the frame
    cv2.putText(

        frame,

        # Display FPS with one decimal place
        f"FPS : {fps:.1f}",

        # Position of the text
        (20, 35),

        # Font style
        cv2.FONT_HERSHEY_SIMPLEX,

        # Font size
        1,

        # Text color (Blue)
        (255, 0, 0),

        # Text thickness
        2
    )

    # --------------------------------------------------
    # Display Face Count
    # --------------------------------------------------

    # Display the total number of detected faces
    cv2.putText(

        frame,

        # Number of detected faces
        f"Faces : {len(faces)}",

        # Position of the text
        (20, 70),

        # Font style
        cv2.FONT_HERSHEY_SIMPLEX,

        # Font size
        0.8,

        # Text color (Red)
        (0, 0, 255),

        # Text thickness
        2
    )

    # Display the final output window
    cv2.imshow("Haar Cascade Face Detection", frame)

    # Wait for 1 millisecond
    # Exit the program when the user presses the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# --------------------------------------------------
# Cleanup
# --------------------------------------------------

# Release the webcam resource
cap.release()

# Close all OpenCV windows
cv2.destroyAllWindows()
